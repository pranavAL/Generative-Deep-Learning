# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavAL/Tutorials-Deep-Learning/blob/main/Image_Classification_With_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###  Importing the modules

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load an Image

# %%
img_path = "sample_data/cat.jpg"
img = image.load_img(img_path, target_size=(224,224))
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Expand the dimension of the given image

# %%
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)

# %% [markdown]
# ### Downloading the pre-trained model

# %%
model = tf.keras.applications.resnet50.ResNet50()
# Out:
# ...
# 102973440/102967424 [==============================] - 2s 0us/step

# %% [markdown]
# ### Merging into a single function

# %%
def classify(img_path):
  img = image.load_img(img_path, target_size=(224,224))
  model = tf.keras.applications.resnet50.ResNet50()
  img_array = image.img_to_array(img)
  img_batch = np.expand_dims(img_array, axis=0)
  img_preprocessed = preprocess_input(img_batch)
  prediction = model.predict(img_preprocessed)
  print(decode_predictions(prediction, top=3)[0])

classify('sample_data/cat.jpg')
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [('n02124075', 'Egyptian_cat', 0.41073498), ('n02123159', 'tiger_cat', 0.33235538), ('n02123045', 'tabby', 0.23437391)]

# %% [markdown]
# ### Testing on different categories

# %%
img_path = "sample_data/dog.jpg"
img = image.load_img(img_path, target_size=(224,224))
plt.imshow(img)
plt.show()

# %%
classify('sample_data/dog.jpg')
# Out:
# [('n02110063', 'malamute', 0.6052755), ('n02109961', 'Eskimo_dog', 0.17718507), ('n02105412', 'kelpie', 0.06618827)]
